# %%
# example_usage.py
import cv2
from xai import run_saliency_analysis

# # Basic usage with minimal parameters
# def basic_example():
#     run_saliency_analysis(
#         model_path='best_Base_Unet_scripted.pt',
#         data_dir='kaggle_3m',
#         num_samples=3
#     )

# # Advanced usage with custom parameters
# def advanced_example():
#     run_saliency_analysis(
#         model_path='best_Base_Unet_scripted.pt',
#         data_dir='kaggle_3m',
#         output_dir='custom_saliency_maps',
#         num_samples=5,
#         prediction_threshold=0.6,  # More conservative threshold
#         saliency_threshold=0.4,    # More sensitive saliency detection
#         overlay_alpha=0.7,         # Stronger overlay
#         colormap=cv2.COLORMAP_INFERNO,  # Different colormap
#         show_plots=True,
#         save_plots=True,
#         # Analyze specific samples
#         sample_indices=[0, 5, 10, 15, 20]  # Specific indices to analyze
#     )

# Analyze an external image
def external_image_example():
    run_saliency_analysis(
        model_path='best_Attresunet_scripted.pt',
        data_dir=None,  # Don't use dataset
        external_image_path="S:\\Projects\\Capstone\\beta_1\\Segmentation\\kaggle_3m\\TCGA_CS_4944_20010208\\TCGA_CS_4944_20010208_9.tif",
        output_dir='external_analysis',
        prediction_threshold=0.5,
        overlay_alpha=0.6,
        colormap=cv2.COLORMAP_HOT
    )

# # Analyze both dataset samples and an external image
# def combined_example():
#     run_saliency_analysis(
#         model_path='best_Base_Unet_scripted.pt',
#         data_dir='kaggle_3m',
#         external_image_path='path/to/your/external/image.jpg',
#         output_dir='combined_analysis',
#         num_samples=2,
#         prediction_threshold=0.5,
#         saliency_threshold=0.5,
#         overlay_alpha=0.5,
#         show_plots=False,  # Don't show plots (useful for batch processing)
#         save_plots=True
#     )

if __name__ == "__main__":
    # Choose which example to run
    # basic_example()
    # advanced_example()
    external_image_example()
    # combined_example()
# Out:
# Using device: cuda
# Processed external image, saved to external_analysis\external_image_saliency.png and external_analysis\external_image_overlay.png
